# %%
import pandas as pd

team_hitter = pd.read_csv('C:/Users/chomjung/OneDrive - 명지대학교/빅콘테스트2020/데이터 전처리/팀타자_세이버 매트릭스_합본_8_25.csv', encoding='CP949')
hitter = pd.read_csv('C:/Users/chomjung/OneDrive - 명지대학교/빅콘테스트2020/데이터 전처리/개인타자_세이버 매트릭스_합본_8_25.csv', encoding='CP949')

# %%
hitter
# Out:
#        Unnamed: 0            게임키          일자 팀코드 상대팀코드  더블헤더코드 초말   선수코드  선발  \
# 0               0  20160401HHLG0  2016-04-01  HH    LG       0  T  60404   0
# 1               1  20160401HHLG0  2016-04-01  LG    HH       0  B  61102   1
# 2               2  20160401HHLG0  2016-04-01  LG    HH       0  B  61186   1
# 3               3  20160401HHLG0  2016-04-01  LG    HH       0  B  62164   0
# 4               4  20160401HHLG0  2016-04-01  HH    LG       0  T  62700   1
# ...           ...            ...         ...  ..   ...     ... ..    ...  ..
# 81097       81097  20200719WOSK0  2020-07-19  SK    WO       0  B  75847   1
# 81098       81098  20200719WOSK0  2020-07-19  SK    WO       0  B  76802   1
# 81099       81099  20200719WOSK0  2020-07-19  SK    WO       0  B  77463   0
# 81100       81100  20200719WOSK0  2020-07-19  WO    SK       0  T  78168   1
# 81101       81101  20200719WOSK0  2020-07-19  WO    SK       0  T  79456   1
#
# ...

# %%
def SecA(row):
    previous = team_hitter[(team_hitter['시즌'] == row['시즌']) & (team_hitter['팀코드'] == row['팀코드']) & (team_hitter['일자'] < row['일자'])]
    if len(previous) == 0:
        row['SecA'] = 0
        return row
    previous_sum = previous.sum()
    up = previous_sum['4구']+(previous_sum['2루타']+previous_sum['3루타']*2+previous_sum['홈런']*3)+previous_sum['도루']-previous_sum['도루실패']
    down = previous_sum['타수']
    if down == 0:
        row['SecA'] = 0
        return row
    row['SecA'] = up/down
    return row
def perSecA(row):
    previous = hitter[hitter['선수코드'] == row['선수코드']].copy()
    previous = previous[(previous['시즌'] == row['시즌']) &(previous['일자'] < row['일자'])]
    previous_sum = previous.sum()
    if len(previous) == 0:
        row['SecA'] = 0
        return row
    up = previous_sum['4구']+(previous_sum['2루타']+previous_sum['3루타']*2+previous_sum['홈런']*3)+previous_sum['도루']-previous_sum['도루실패']
    down = previous_sum['타수']    
    if down == 0:
        row['SecA'] = 0
        return row
    row['SecA'] = up/down   
    return row

# %%
team_hitter = team_hitter.apply(SecA, axis=1)

# %%
hitter = hitter.apply(perSecA, axis = 1)

# %%
team_hitter.to_csv("./팀타자 최종.csv",encoding = 'CP949', index = False)

# %%
hitter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5b1c6a242410> in <module>
# ----> 1 hitter
#
# NameError: name 'hitter' is not defined
